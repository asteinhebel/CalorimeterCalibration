# %%
using LCIO
using Plots
using Glob
using LsqFit
using StatsBase
using Distributions
gr();

# %%
# read the files for calibration
fileList = readdir(glob"reco_1000a*randPhi*", "singleParticles")
# build the list of input energies
energyString = r"_(\d+)GeV"
# get (match) the energy string from the filename, convert (parse) from string to Int16, build a dictionary from ints to filenames
energyMap = Dict((parse(Int16, match(energyString, fn)[1]), fn) for fn in fileList)
for (energy, filename) in energyMap
    println(energy, " GeV:\t", filename)
end
# Out:
# 20 GeV:	singleParticles/reco_1000a_20GeV_randPhi.slcio
# 100 GeV:	singleParticles/reco_1000a_100GeV_randPhi.slcio
# 10 GeV:	singleParticles/reco_1000a_10GeV_randPhi.slcio
# 50 GeV:	singleParticles/reco_1000a_50GeV_randPhi.slcio
# 2 GeV:	singleParticles/reco_1000a_2GeV_randPhi.slcio
# 5 GeV:	singleParticles/reco_1000a_5GeV_randPhi.slcio
# 1 GeV:	singleParticles/reco_1000a_1GeV_randPhi.slcio

# %%
function getHitsFromFile(filename)
    eCalEnergies = Float64[]
    hCalEnergies = Float64[]
    eCalLengths = Int16[]
    hCalLengths = Int16[]
    LCIO.open(filename) do reader
        for (idx, event) in enumerate(reader)
            if idx > 10000
                break
            end
            hCalEnergy = 0.0
            hCalLength = 0
            eCalEnergy = 0.0
            eCalLength = 0
            # sum up the uncalibrated HCalHits
            for hit in getCollection(event, "HCalBarrelHits")
                hCalEnergy += getEnergy(hit)
                hCalLength += 1
            end
            # sum up the uncalibrated ECalHits
            # this needs to be sorted by layer, so we need a decoder
            EcalBarrelHits = getCollection(event, "ECalBarrelHits")
            decode = CellIDDecoder(EcalBarrelHits)
            for hit in EcalBarrelHits
                # calibrate the hits in the later layers with a higher number,
                # because they are behind thicker tungsten slabs
                factor = decode(hit)["layer"] < 21 ? 1 : 2
                if decode(hit)["layer"]>0
                    eCalEnergy += factor*getEnergy(hit)
                    eCalLength += 1
                end
            end
            # fixme: Simple outlier cut
            if eCalLength+hCalLength < 100
                continue
            end
            push!(eCalEnergies, eCalEnergy)
            push!(eCalLengths, eCalLength)
            push!(hCalEnergies, hCalEnergy)
            push!(hCalLengths, hCalLength)
        end
    end
    return eCalEnergies, eCalLengths, hCalEnergies, hCalLengths
end;

# %%
eHits  = Dict{Int16, Vector{Float64}}()
eCount = Dict{Int16, Vector{Int16}}()
hHits  = Dict{Int16, Vector{Float64}}()
hCount = Dict{Int16, Vector{Int16}}()
for (energy, filename) in energyMap
    if energy < 10
        continue
    end
    println("Processing file for ", energy, " GeV")
    eCal, nEhits, hCal, nHhits = getHitsFromFile(filename)
    eHits[energy] = eCal
    eCount[energy] = nEhits
    hHits[energy] = hCal
    hCount[energy] = nHhits
end
# Out:
# Processing file for 20 GeV
# Processing file for 100 GeV
# Processing file for 10 GeV
# Processing file for 50 GeV

# %%
# removes the 10% of the furthest outliers on either side
# no assumption about smoothness
function removeTails(distribution, cutOff=10)
    sort!(distribution)
    l = length(distribution)
    lcut = round(Int64, l * cutOff/100)
    hcut = round(Int64, l * (100-cutOff)/100)
    # start out with the whole distribution
    minDist = distribution[end] - distribution[1]
    low = 1
    high = l
    for idx = 1:lcut
        dist = distribution[hcut+idx] - distribution[idx]
        if dist < minDist
            minDist = dist
            low = idx+1
            high = hcut+idx
        end
    end
    return low, high
end;

# %%
function fitter(ecal, hcal, energy)
    function model(x, p)
        return p[1] .* x[1] + p[2] .* x[2]
    end
    fit = curve_fit(model, [ecal, hcal], energy, [50.0, 35.0])
    return fit.param
end
hCalCalibration = Dict{Int16, Float64}()
eCalCalibration = Dict{Int16, Float64}()
for energy in keys(hHits)
    ecal = eHits[energy]
    hcal = hHits[energy]
    calibration = fitter(ecal, hcal, energy)
    eCalCalibration[energy] = calibration[1]
    hCalCalibration[energy] = calibration[2]
    println(energy, " GeV: \t", eCalCalibration[energy], "\t", hCalCalibration[energy])
end
# Out:
# 100 GeV: 	58.6523574051394	37.75035684356638
# 10 GeV: 	57.94287970934826	44.864783755246215
# 50 GeV: 	58.48734753774342	41.489776324655224
# 20 GeV: 	58.25774131952661	40.497195904054095

# %%
histogram([eCalCalibration[energy] .* eHits[energy] .+ hCalCalibration[energy] .* hHits[energy] for energy in keys(hHits)], fillalpha=0.5, linewidth=0, label=map(string, keys(hHits)))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   99.4962,379.237 99.4962,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   212.488,379.237 212.488,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   325.48,379.237 325.48,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   438.471,379.237 438.471,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   551.463,379.237 551.463,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,384.952 587.581,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,318.107 587.581,318.107
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,251.262 587.581,251.262
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,184.418 587.581,184.418
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,117.573 587.581,117.573
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,50.7283 587.581,50.7283
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   99.4962,384.952 99.4962,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   212.488,384.952 212.488,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   325.48,384.952 325.48,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   438.471,384.952 438.471,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   551.463,384.952 551.463,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 39.0856,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,318.107 39.0856,318.107
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,251.262 39.0856,251.262
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,184.418 39.0856,184.418
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,117.573 39.0856,117.573
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,50.7283 39.0856,50.7283
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 99.4962, 396.952)" x="99.4962" y="396.952">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.488, 396.952)" x="212.488" y="396.952">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 325.48, 396.952)" x="325.48" y="396.952">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 438.471, 396.952)" x="438.471" y="396.952">80</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 551.463, 396.952)" x="551.463" y="396.952">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 389.452)" x="29.4037" y="389.452">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 322.607)" x="29.4037" y="322.607">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 255.762)" x="29.4037" y="255.762">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 188.918)" x="29.4037" y="188.918">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 122.073)" x="29.4037" y="122.073">80</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 55.2283)" x="29.4037" y="55.2283">100</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 509.815,378.267 509.815,384.952 512.606,384.952 512.606,378.267 509.815,378.267 509.815,378.267
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   509.815,378.267 509.815,384.952 512.606,384.952 512.606,378.267 509.815,378.267
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 512.606,381.61 512.606,384.952 515.398,384.952 515.398,381.61 512.606,381.61 512.606,381.61
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; s

# %%
# this function attempts a global fit and minimizes the offset b of the linear form y=mx+b
# parameters are ecal energies (×2 for the hits in the outer layers), hcal energies, particle energy
function lineFitter(ecal, hcal, truValues)
    function model(x, p)
        energies = Dict{Int16, Float64}()
        for e in truValues
            calibrated = p[1] .* x[1][e] + p[2] .* x[2][e]
            # cut the tails, fit a Normal distribution to the result
            low, high = removeTails(calibrated)
            n = Distributions.fit(Normal, calibrated[low:high])
            energies[e] = n.μ
        end
        # we are optimizing for the ratio of reconstructed energies to true values
        return [energies[e]/e for e in truValues]
    end
    fit = curve_fit(model, [ecal, hcal], 1.0, [50.0, 36.0])
    return fit.param
end
ECal, HCal = lineFitter(eHits, hHits, keys(hHits))
println("ECal calibration constant: ", ECal)
println("HCal calibration constant: ", HCal)
# Out:
# ECal calibration constant: 57.92185276857112
# HCal calibration constant: 100.37998956808227

# %%
histogram([ECal .* eHits[energy] .+ HCal .* hHits[energy] for energy in keys(hHits)], fillalpha=0.5, linewidth=0, label=map(string, keys(hHits)))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   230.155,379.237 230.155,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   466.635,379.237 466.635,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,384.952 587.581,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,289.22 587.581,289.22
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,193.487 587.581,193.487
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,97.7547 587.581,97.7547
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   230.155,384.952 230.155,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   466.635,384.952 466.635,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 39.0856,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,289.22 39.0856,289.22
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,193.487 39.0856,193.487
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,97.7547 39.0856,97.7547
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 230.155, 396.952)" x="230.155" y="396.952">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 466.635, 396.952)" x="466.635" y="396.952">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 389.452)" x="29.4037" y="389.452">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 293.72)" x="29.4037" y="293.72">50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 197.987)" x="29.4037" y="197.987">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 102.255)" x="29.4037" y="102.255">150</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 432.312,383.037 432.312,384.952 437.611,384.952 437.611,383.037 432.312,383.037 432.312,383.037
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   432.312,383.037 432.312,384.952 437.611,384.952 437.611,383.037 432.312,383.037
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 437.611,367.72 437.611,384.952 442.911,384.952 442.911,367.72 437.611,367.72 437.611,367.72
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   437.611,367.72 437.611,384.952 442.911,384.952 442.911,367.72 437.611,367.72
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 442.911,317.939 442.911,384.952 448.21,384.952 448.21,317.939 442.911,317.939 442.911,317.939
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   442.911,317.939 442.911,384.952 448.21,384.952 448.21,317.939 442.911,317.939
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 448.21,264.329 448.21,384.952 453.509,384.952 453.509,264.329 448.21,264.329 448.21,264.329
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   448.21,264.329 448.21,384.952 453.509,384.952 453.509,264.329 448.21,264.329
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 453.509,141.792 453.509,384.952 458.809,384.952 458.809,141.792 453.509,141.792 453.509,141.792
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   453.509,141.792 453.509,384.952 458.809,384.952 458.809,141.792 453.509,141.792
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 458.809,92.0108 458.809,384.952 464.108,384.952 464.108,92.0108 458.809,92.0108 458.809,92.0108
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   458.809,92.0108 458.809,384.952 464.108,384.952 464.108,92.0108 458.809,92.0108
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 464.108,3.93701 464.108,384.952 469.408,384.952 469.408,3.93701 464.108,3.93701 464.108,3.93701
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   464.108,3.93701 464.108,384.952 469.408,384.952 469.408,3.93701 464.108,3.93701
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 469.408,67.1204 469.408,384.952 474.707,384.952 474.707,67.1204 469.408,67.1204 469.408,67.1204
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   469.408,67.1204 469.408,384.952 474.707,384.952 474.707,67.1204 469.408,67.1204
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 474.707,174.341 474.707,384.952 480.006,384.952 480.006,174.341 474.707,174.341 474.707,174.341
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:1; fill:none" points="
#   474.707,174.341 474.707,384.952 480.006,384.952 480.006,174.341 474.707,174.341
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 480.006,247.097 480.006,384.952 485.306,384.952 485.306,

# %%
y = Vector{Float64}()
yerr = Vector{Float64}()
x = Vector{Float64}()
for e in keys(hHits)
    d = ECal .* eHits[e] .+ HCal .* hHits[e]
    low, high = removeTails(d)
    gauss = Distributions.fit(Normal, d[low:high])
    push!(y, gauss.μ)
    push!(yerr, gauss.σ)
    push!(x, 1.0*e)
end
line(x, p) = p[1] + p[2]*x
l = curve_fit(line, x, y, [0.0, 1.0])
plot(x, y, yerr=yerr, marker=stroke(2), line=false, label="data")
leg = @sprintf("y=%.2f + %.2f*x", l.param[1], l.param[2])
plot!(x, l.param[1]+l.param[2]*x, label=leg)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   105.88,379.237 105.88,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   224.425,379.237 224.425,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   342.97,379.237 342.97,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   461.514,379.237 461.514,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   580.059,379.237 580.059,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,333.388 587.581,333.388
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,255.525 587.581,255.525
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,177.662 587.581,177.662
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,99.7987 587.581,99.7987
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.0856,21.9357 587.581,21.9357
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 596.063,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   105.88,384.952 105.88,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   224.425,384.952 224.425,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   342.97,384.952 342.97,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   461.514,384.952 461.514,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   580.059,384.952 580.059,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,384.952 30.6037,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,333.388 39.0856,333.388
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,255.525 39.0856,255.525
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,177.662 39.0856,177.662
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,99.7987 39.0856,99.7987
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   30.6037,21.9357 39.0856,21.9357
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 105.88, 396.952)" x="105.88" y="396.952">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 224.425, 396.952)" x="224.425" y="396.952">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 342.97, 396.952)" x="342.97" y="396.952">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 461.514, 396.952)" x="461.514" y="396.952">80</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.059, 396.952)" x="580.059" y="396.952">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 337.888)" x="29.4037" y="337.888">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 260.025)" x="29.4037" y="260.025">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 182.162)" x="29.4037" y="182.162">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 104.299)" x="29.4037" y="104.299">80</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4037, 26.4357)" x="29.4037" y="26.4357">100</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0; stroke-opacity:1; fill:none" points="
#   580.059,22.1535 46.6072,372.264 283.697,216.71 105.88,333.394
#   "/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="580.059" cy="22.1535" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="580.059" cy="22.1535" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="46.6072" cy="372.264" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="46.6072" cy="372.264" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="283.697" cy="216.71" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="283.697" cy="216.71" r="2"/>
# <circle clip-path="url(#clip02)" style="fill:#00002d; stroke:none; fill-opacity:1" cx="105.88" cy="333.394" r="4"/>
# <circle clip-path="url(#clip02)" style="fill:#0099ff; stroke:none; fill-opacity:1" cx="105.88" cy="333.394" r="2"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1.6; stroke-opacity:1; fi
